# %% [markdown]
# <a href="https://colab.research.google.com/github/sunil364/NLP_Project_2/blob/main/Untitled228.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
List1=[1,2,3,4,5]
List2=[2,3,4,5,6,7]

# %%
def max_comman_element(List1,List2):
  for i in range(0, 5):
    return max(List1[i])
    for j in List2:
      if i==j:
        return i
print(max_comman_element(List1,List2))
# Out:
# 2

# %%
email=input("enter your email :")
password=input('Enter your password :')
if email=="verma.sunil364@gmail.com" and password=="Sunil@364":
  print("Welcome to the Data Science world")
else:
  print("Invalid credentials")
# Out:
# enter your email :12453
# Enter your password :1234
# Invalid credentials

# %%
number=int(input("Enter a anumber: "))
i=1
while i<11:
  print(number*i)
  i+=1
# Out:
# Enter a anumber: 12
# 12
# 24
# 36
# 48
# 60
# 72
# 84
# 96
# 108
# 120

# %%
number=input("Enter a number : ")
i=1
while i<11:
  print(number*i)
  i+=1
# Out:
# Enter a number : 13
# 13
# 1313
# 131313
# 13131313
# 1313131313
# 131313131313
# 13131313131313
# 1313131313131313
# 131313131313131313
# 13131313131313131313

# %%
num=int(input("Enter a number : "))
i=0
while i<11:
  print(num*i)
  i+=1
# Out:
# Enter a number : 15
# 0
# 15
# 30
# 45
# 60
# 75
# 90
# 105
# 120
# 135
# 150

# %%
# Guessing game
import random
jack_pot=random.randint(1,100)

guess=int(input("Enter a number : "))
counter=1
while guess!= jack_pot:
  if guess<jack_pot:
     print("Guess higher")
  else:
    print("Guess lower")
    guess=int(input("Enter a number : "))
    counter+=1
print("Sahi jawab")
print("Yo took",counter, "attempts" )
# Out:
# Streaming output truncated to the last 5000 lines.
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# Guess higher
# ...

# %%
marks=int(input("enter marks:"))
if marks>=35:
  print("pass")
  if marks>80:
    print("A grade")
  else:
    print("You pass but you have not secure A grade")
else:
  print("fail")
# Out:
# enter marks:56
# pass
# You pass but you have not secure A grade

# %% [markdown]
# 2.

# %%
age=int(input("Enter your age :"))
crime_record=input("Enter your crime record: ")
if age>=18:
  if crime_record=="no":
    print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# Enter your age :20
# Enter your crime record: no
# You are eligible to vote

# %% [markdown]
# 3.

# %%
age=int(input("Enter your age :"))
crime_record=input("Are there any crime record yes/no: ")
if age>=18 and crime_record=="no":
  print("Eligible to vote")
else:
  print("Not eligible to vote")
# Out:
# Enter your age :30
# Are there any crime record yes/no: no
# Eligible to vote

# %% [markdown]
# 4.

# %%
f_name=input("Enter your first name :")
l_name=input("Enter your last name :")
print("Your name is : " +f_name+" "+l_name)
# Out:
# Enter your first name :sunil
# Enter your last name :verma
# Your name is : sunil verma
